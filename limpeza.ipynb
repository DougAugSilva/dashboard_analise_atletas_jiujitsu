# %% [markdown]
# # Explorando um pouco os Dados

# %%
import pandas as pd

# %%
df = pd.read_csv('atletas.csv', sep=';')

# %%
df.head()
# Out:
#    Position                                              Photo  \
# 0         2  https://api.ibjjfdb.com/Athletes/56444/Ranking...
# 1         3  https://api.ibjjfdb.com/Athletes/82191/Ranking...
# 2         4  https://api.ibjjfdb.com/Athletes/181449/Rankin...
# 3         5  https://api.ibjjfdb.com/Athletes/121461/Rankin...
# 4         6  https://api.ibjjfdb.com/Athletes/84404/Ranking...
#
#                                   Name  \
# 0                Adam Piotr Wardzinski
# 1               Diego Oliveira Batista
# 2                Alexandre Papa Manara
# 3  Marcus Vinicius Ribeiro de Siqueira
# 4     Dayvison Lucas Miranda L. Calado
#
#                                              Details                 Academy  \
# 0         https://ibjjf.com/athletes/adam-wardzinski  CheckMat International
# 1  https://ibjjf.com/athletes/diego-batista-65fb1...                     AOJ
# 2        https://ibjjf.com/athletes/alexandre-manara              Lotus Club
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5400 entries, 0 to 5399
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  5400 non-null   int64
#  1   Photo     900 non-null    object
#  2   Name      5400 non-null   object
#  3   Details   5400 non-null   object
#  4   Academy   5400 non-null   object
#  5   Points    5400 non-null   float64
#  6   Kimono    5400 non-null   object
#  7   Category  5400 non-null   object
#  8   Gender    5400 non-null   object
#  9   Belt      5400 non-null   object
#  10  Division  5400 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 464.2+ KB
