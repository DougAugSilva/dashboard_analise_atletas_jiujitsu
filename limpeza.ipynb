# %% [markdown]
# # Explorando um pouco os Dados

# %%
import pandas as pd

# %%
df = pd.read_csv('atletas.csv', sep=';')

# %%
df.head()
# Out:
#    Position                                              Photo  \
# 0         1  https://api.ibjjfdb.com/Athletes/58697/Ranking...
# 1         2  https://api.ibjjfdb.com/Athletes/42049/Ranking...
# 2         3  https://api.ibjjfdb.com/Athletes/88234/Ranking...
# 3         4  https://api.ibjjfdb.com/Athletes/212988/Rankin...
# 4         5  https://api.ibjjfdb.com/Athletes/128358/Rankin...
#
#                                Name  \
# 0         Michael Jalen B. Fonacier
# 1              Samuel David Marquez
# 2  Carlos Alberto Oliveira da Silva
# 3             Lucas de Souza Castro
# 4          Thalison Vitorino Soares
#
#                                              Details  \
# 0        https://ibjjf.com/athletes/michael-fonacier
# 1          https://ibjjf.com/athletes/samuel-marquez
# 2  https://ibjjf.com/athletes/carlos-silva-08a7e4...
# 3  https://ibjjf.com/athletes/lucas-castro-bd7e9e...
# 4  https://ibjjf.com/athletes/thalison-soares-4b8...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3731 entries, 0 to 3730
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  3731 non-null   int64
#  1   Photo     3731 non-null   object
#  2   Name      3731 non-null   object
#  3   Details   3731 non-null   object
#  4   Academy   3731 non-null   object
#  5   Points    3731 non-null   float64
#  6   Kimono    3731 non-null   object
#  7   Category  3731 non-null   object
#  8   Gender    3731 non-null   object
#  9   Belt      3731 non-null   object
#  10  Division  3731 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 320.8+ KB

# %%
#seleciona categorias únicas
divisions = df['Division'].unique()
print(divisions)
# Out:
# ['rooster' 'lightfeather' 'feather' 'light' 'middle' 'mediumheavy' 'heavy'
#  'superheavy' 'ultraheavy' 'openclass']

# %%
df[df['Division'] == 'ultraheavy']
# Out:
#       Position                                              Photo  \
# 2037         1  https://api.ibjjfdb.com/Athletes/181449/Rankin...
# 2038         2  https://api.ibjjfdb.com/Athletes/121461/Rankin...
# 2039         3  https://api.ibjjfdb.com/Athletes/168594/Rankin...
# 2040         4  https://api.ibjjfdb.com/Athletes/243940/Rankin...
# 2041         5  https://api.ibjjfdb.com/Athletes/132239/Rankin...
# ...        ...                                                ...
# 2303       247  https://api.ibjjfdb.com/Athletes/194281/Rankin...
# 2304       247  https://api.ibjjfdb.com/Athletes/36636/Ranking...
# 2305       247  https://api.ibjjfdb.com/Athletes/430878/Rankin...
# 2306       247  https://api.ibjjfdb.com/Athletes/37882/Ranking...
# 2307       247  https://api.ibjjfdb.com/Athletes/86054/Ranking...
#
#                                      Name  \
# 2037                Alexandre Papa Manara
# 2038  Marcus Vinicius Ribeiro de Siqueira
# 2039            Luis Fernando de Oliveira
# ...
